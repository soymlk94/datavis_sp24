# %% [markdown]
# <a href="https://colab.research.google.com/github/soymlk94/datavis_sp24/blob/main/ps_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PS 5
#
# (Cervical Cancer & Inequity in NJ) - Where you live and who you are still matter when it comes to cervical cancer risk — and we can see it clearly in the gaps in screening, outcomes, and access.

# %% [markdown]
# In PS5 we will look at specfically invasive cervical cancer in the state of New Jersey (***Determinants of Abnormal Cervical Cancer Screening Follow-Up And Invasive Cervical Cancer Among Uninsured and Underinsured Women in New Jersey***)
#
# Identify determinants of follow-up care and diagnosis of invasive cervical cancer among uninsured/underinsured women screened for cervical cancer. Methods. We examined the associations between health care facility, area-level, and individual-level factors on the outcomes of interest in invase cervical cancer beetween
#
# Individual-level factors, including socioeconomic status, insurance status, age, race/ethnicity, prior Pap test abnormalities, and health literacy, as well as neighborhood socioeconomic deprivation have been well documented to be associated with the lack of and longer intervals of timely follow-up care. However, while provider-level and system-level factors are also recognized as part of the multilevel influences on cancer care delivery and outcomes few studies have explored the association between these factors and adherence to follow-up of abnormal cervical cancer screening results, particularly among rarely screened populations.
#
# While invasive cervical cancer incidence and mortality rates have declined greatly in the past several decades, the rates have stabilized in recent years1 and racial, ethnic, and socioeconomic disparities persist. For U.S. women, the 2009 age-adjusted incidence rates per 100,000 were higher among Hispanics (14.4) and Blacks (12.6) than Whites (9.5) and Asians/Pacific Islanders (API) (8.8).2 Among women of each race and ethnicity, incidence rates were higher in each successively lower socioeconomic status (SES) group. In New Jersey (NJ), the 2005–2009 age-adjusted invasive cervical cancer incidence rates per 100,000 women also were higher among Hispanics (12.8) and Blacks
#
# New Jersey’s invasive cervical cancer incidence rate tied for 10th highest among the 50 states and District of Columbia
#
# Now, invasive cervical cancer can be prevented almost entirely by a combination of Papanicolaou (Pap) testing and HPV vaccination.1 Despite its preventability, cases of invasive cervical cancer continue to occur due to a lack of Pap screening among adult women and HPV vaccination among adolescent and young women
#
# Coverage was lowest nationwide for White or Black non-Hispanic female adolescents and female adolescents at or above poverty level.9 Young (18–26) U.S. women’s HPV vaccination initiation rate (one or more doses) also is low, although it increased from 11.6% in 2008 to 34.1% in 2012.10 Black women, Hispanic women, uninsured women and women with no usual place of care had the lowest 2012 HPV vaccination initiation rates
#
# The purpose of this study was to identify geographic areas in NJ with significantly higher risk of invasive cervical cancer incidence or late-stage diagnosis and to ascertain the relationship between demographic and socioeconomic (SES) characteristics and higher risks in these areas.
#
# Methods and Explination - SaTScan software (version 9.1.1.) was used to identify geographic areas of significantly higher invasive cervical cancer incidence rates (HIAs) or higher proportions of cases diagnosed in the late stage (regional and distant stages).
#
# Odds ratios (ORs) assessing the associations between the statistically significant characteristics from the univariate analysis (independent variables) and being a case in a HIA versus being a case in the rest of the state (dependent variable) were produced from multiple logistic regression models that included all the significant characteristics. Due to small numbers in two HIAs, similar insurance categories were combined: 1) Medicare and other government and 2) uninsured and Medicaid
#
# Three significant invasive cervical cancer HIAs were found in: northeastern NJ, primarily Newark, Essex County and Elizabeth, Union County (HIA 1); central NJ, primarily Trenton, Mercer County (HIA 2); and southwestern NJ, primarily Camden City, Camden County (HIA 3).
#
# Data - Conducted a retrospective cohort study of women screened for cervical cancer in the NJCEED Program from 2000 to 2015
#
# Citatations - Roche, L. M., Niu, X., & Henry, K. A. (2015). Invasive cervical cancer incidence disparities in New Jersey—a spatial analysis in a high incidence state. Journal of Health Care for the Poor and Underserved, 26(4), 1173–1185. https://doi.org/10.1353/hpu.2015.0127
#
# Citations for Figures - Geographic areas with significantly higher age-adjusted invasive cervical cancer incidence rates among women 20 and older, New Jersey, 2005–2009.
#
# Data derived from Figure 1, Table 1, Table 2, and Table 3 of Roche, L. M., Niu, X., & Henry, K. A. (2015).

# %%
# Install gdown (if not already installed)
# !pip install gdown

# Download the image from Google Drive using its file ID
import gdown
file_id = "1RIAURIuh5u_4Odg_UER--E27Agpsx3Il"
gdown.download(f"https://drive.google.com/uc?id={file_id}", "NJ_Cancer_Map.png", quiet=False)

# Display the image from local file
from IPython.display import Image, display
display(Image("NJ_Cancer_Map.png"))
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From: https://drive.google.com/uc?id=1RIAURIuh5u_4Odg_UER--E27Agpsx3Il
# To: /content/NJ_Cancer_Map.png
# 100%|██████████| 147k/147k [00:00<00:00, 7.30MB/s]

# %% [markdown]
# The three invasive cervical cancer HIAs contain about 8.1% of NJ’s population and 7.8% of NJ’s women age 20 or older. **Nearly half the population in each HIA is Black and nearly a third Hispanic, whereas only about 11% and 15% of the population in the rest of the state are Black and Hispanic, respectively.** **Higher percentages of the populations in the HIAs are foreign born (except HIA 3), speak English less than well, speak Spanish at home, have less than a high school education, are not married, are unemployed, have a family income below poverty, and are in rental occupied housing**. Per capita income in the three HIAs is about half that in the rest of the state

# %% [markdown]
# ***Cervical Cancer Stage at Diagnosis by Region (Stacked Bar Chart)***
#
# Why: Shows disparities in early vs. late detection.
# Expected Finding: Geographic Areas 1–3 have higher rates of regional/distant diagnoses vs. Rest of NJ.
# Message: Early detection is worse in high-risk areas.

# %%
import pandas as pd
import plotly.express as px

# --- Graph 1: Stage at Diagnosis by Region ---

stage_data = {
    "Region": ["Geographic Area 1", "Geographic Area 2", "Geographic Area 3", "Rest of NJ"],
    "Local": [92, 5, 15, 809],
    "Regional": [91, 15, 15, 645],
    "Distant": [16, 9, 3, 198],
    "Unknown": [27, 6, 2, 88]
}
df_stage = pd.DataFrame(stage_data)
df_stage_long = df_stage.melt(id_vars="Region", var_name="Stage", value_name="Count")
df_stage_long["Percent"] = df_stage_long.groupby("Region")["Count"].transform(lambda x: x / x.sum() * 100)

fig1 = px.bar(
    df_stage_long, x="Region", y="Percent", color="Stage", text="Count",
    title="Stage at Cervical Cancer Diagnosis by Region (Interactive)",
    labels={"Percent": "Percentage of Cases"},
    color_discrete_sequence=px.colors.qualitative.Set2
)
fig1.update_traces(textposition='inside')
fig1.update_layout(barmode="stack", template="plotly_white", title_font_size=18)
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f700dc4c-c597-4922-8f84-e3dd14f16930" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f700dc4c-c597-4922-8f84-e3dd14f16930")) {                    Plotly.newPlot(                        "f700dc4c-c597-4922-8f84-e3dd14f16930",                        [{"alignmentgroup":"True","hovertemplate":"Stage=Local\u003cbr\u003eRegion=%{x}\u003cbr\u003ePercentage of Cases=%{y}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Local","marker":{"color":"rgb(102,194,165)","pattern":{"shape":""}},"name":"Local","offsetgroup":"Local","orientation":"v","showlegend":true,"text":[92.0,5.0,15.0,809.0],"textposition":"inside","x":["Geographic Area 1","Geographic Area 2","Geographic Area 3","Rest of NJ"],"xaxis":"x","y":[40.707964601769916,14.285714285714285,42.857142857142854,46.49425287356322],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Stage=Regional\u003cbr\u003eRegion=%{x}\u003cbr\u003ePercentage of Cases=%{y}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Regional","marker":{"color":"rgb(252,141,98)","pattern":{"shape":""}},"name":"Regional","offsetgroup":"Regional","orientation":"v","showlegend":true,"text":[91.0,15.0,15.0,645.0],"textposition":"inside","x":["Geographic Area 1","Geographic Area 2","Geographic Area 3","Rest of NJ"],"xaxis":"x","y":[40.26548672566372,42.857142857142854,42.857142857142854,37.06896551724138],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Stage=Distant\u003cbr\u003eRegion=%{x}\u003cbr\u003ePercentage of Cases=%{y}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Distant","marker":{"color":"rgb(141,160,203)","pattern":{"shape":""}},"name":"Distant","offsetgroup":"Distant","orientation":"v","showlegend":true,"text":[16.0,9.0,3.0,198.0],"textposition":"inside","x":["Geographic Area 1","Geographic Area 2","Geographic Area 3","Rest of NJ"],"xaxis":"x","y":[7.079646017699115,25.71428571428571,8.571428571428571,11.379310344827587],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Stage=Unknown\u003cbr\u003eRegion=%{x}\u003cbr\u003ePercentage of Cases=%{y}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Unknown","marker":{"color":"rgb(231,138,195)","pattern":{"shape":""}},"name":"Unknown","offsetgroup":"Unknown","orientation":"v","showlegend":true,"text":[27.0,6.0,2.0,88.0],"textposition":"inside","x":["Geographic Area 1","Geographic Area 2","Geographic Area 3","Rest of NJ"],"xaxis":"x","y":[11.946902654867257,17.142857142857142,5.714285714285714,5.057471264367816],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555 ...

# %% [markdown]
# What the Data Says:
# Women in Geographic Areas 1–3 (the high-risk clusters) are less likely to be diagnosed at the "local" stage compared to the rest of New Jersey.
#
# Geographic Area 2 **stands out with the lowest rate of early-stage detection (just ~14%)** and the highest proportion of distant/unknown stage diagnoses.
# The Rest of NJ has the best screening outcomes, with nearly half of cases detected early.
#
# Interpretation:
# ***This suggests systemic barriers to early detection in the high-risk clusters*** — possibly tied to lack of access to care, lower health literacy, or delayed screening.

# %% [markdown]
# What the Data Tells Us:
# Race matters: Black women in Geographic Area 1 have over 12 times the odds of cervical cancer compared to white/API/other — a stark disparity.
# Ethnicity also plays a role: Hispanic women in Area 1 have 6.4x the odds.
# Insurance status: Being on Medicaid or uninsured significantly increases risk — especially in Area 2 (OR = 3.2).
# Marital status (as a proxy for support/access): not being married raises odds across all regions.
#
# Interpretation:
# Disparities aren’t just medical — they’re structural. These data reveal how race, ethnicity, and access to care fundamentally shape who gets diagnosed, and when.

# %% [markdown]
#  Education Levels by Region (Bar Chart)
#
# Why: Simple but powerful socioeconomic indicator.
# Expected Finding: <HS education: Area 3 ~33% vs Rest of NJ ~12%.
# Message: Disadvantage clusters geographically.

# %%
import plotly.express as px
import pandas as pd

# Data
data_edu = {
    "Region": ["Geographic Area 1", "Geographic Area 2", "Geographic Area 3", "Rest of NJ"],
    "Less than HS Diploma (%)": [27.7, 33.4, 32.9, 11.9]
}
df_edu = pd.DataFrame(data_edu)

# Create an interactive Plotly scatter plot
fig = px.scatter(
    df_edu,
    x="Less than HS Diploma (%)",
    y="Region",
    size="Less than HS Diploma (%)",
    color="Less than HS Diploma (%)",
    color_continuous_scale="Viridis",
    text="Less than HS Diploma (%)",
    title=" Educational Disadvantage by Region (Interactive View)"
)

# Customize look
fig.update_traces(marker=dict(line=dict(width=1, color='DarkSlateGrey')), textposition='middle right')
fig.update_layout(
    xaxis_title="Percent with Less than High School Education",
    yaxis_title="",
    coloraxis_colorbar=dict(title="% <HS"),
    template="plotly_white",
    title_font_size=18,
    width=800,
    height=500
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="82baaace-54e5-4dde-83ed-b6b7d36d8dda" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82baaace-54e5-4dde-83ed-b6b7d36d8dda")) {                    Plotly.newPlot(                        "82baaace-54e5-4dde-83ed-b6b7d36d8dda",                        [{"hovertemplate":"Less than HS Diploma (%)=%{marker.color}\u003cbr\u003eRegion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[27.7,33.4,32.9,11.9],"coloraxis":"coloraxis","size":[27.7,33.4,32.9,11.9],"sizemode":"area","sizeref":0.08349999999999999,"symbol":"circle","line":{"color":"DarkSlateGrey","width":1}},"mode":"markers+text","name":"","orientation":"h","showlegend":false,"text":[27.7,33.4,32.9,11.9],"x":[27.7,33.4,32.9,11.9],"xaxis":"x","y":["Geographic Area 1","Geographic Area 2","Geographic Area 3","Rest of NJ"],"yaxis":"y","type":"scatter","textposition":"middle right"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{ ...

# %% [markdown]
# Key Takeaway:
# Educational disadvantage is significantly higher in the three high-risk geographic areas (28–33%) compared to the Rest of New Jersey (12%).
# This suggests that limited education may be a structural contributor to delayed screening, low health literacy, and reduced access to preventive care — all of which impact cervical cancer risk.

# %% [markdown]
#  Insurance Status of Diagnosed Women by Region (Stacked Bar)
#
# Why: Connects access to care with outcomes.
# Expected Finding: Geographic Areas have more uninsured and Medicaid recipients.
# Message: Lack of insurance likely delays screening/treatment.

# %%
import pandas as pd
import plotly.express as px

# Insurance data from your study
data_insurance = {
    "Region": ["Geographic Area 1", "Geographic Area 2", "Geographic Area 3", "Rest of NJ"],
    "Private": [33, 5, 10, 453],
    "Uninsured/Medicaid": [163, 24, 43, 611],
    "Medicare/Other Gov.": [30, 6, 12, 734]
}

df = pd.DataFrame(data_insurance)
df_long = df.melt(id_vars="Region", var_name="Insurance Type", value_name="Count")

# Convert to percent per region
df_long["Percent"] = df_long.groupby("Region")["Count"].transform(lambda x: x / x.sum() * 100)

# Radar plot
fig = px.line_polar(
    df_long,
    r="Percent",
    theta="Insurance Type",
    color="Region",
    line_close=True,
    markers=True,
    title="Insurance Type Distribution Among Diagnosed Patients (Radar View)",
    color_discrete_sequence=px.colors.qualitative.Bold
)

fig.update_layout(
    template="plotly_white",
    polar=dict(radialaxis=dict(visible=True, range=[0, 100])),
    width=700,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="669d8f49-ede6-4d84-be81-0a7664aaca19" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("669d8f49-ede6-4d84-be81-0a7664aaca19")) {                    Plotly.newPlot(                        "669d8f49-ede6-4d84-be81-0a7664aaca19",                        [{"hovertemplate":"Region=Geographic Area 1\u003cbr\u003ePercent=%{r}\u003cbr\u003eInsurance Type=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Geographic Area 1","line":{"color":"rgb(127, 60, 141)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Geographic Area 1","r":[14.601769911504425,72.12389380530973,13.274336283185843,14.601769911504425],"showlegend":true,"subplot":"polar","theta":["Private","Uninsured\u002fMedicaid","Medicare\u002fOther Gov.","Private"],"type":"scatterpolar"},{"hovertemplate":"Region=Geographic Area 2\u003cbr\u003ePercent=%{r}\u003cbr\u003eInsurance Type=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Geographic Area 2","line":{"color":"rgb(17, 165, 121)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Geographic Area 2","r":[14.285714285714285,68.57142857142857,17.142857142857142,14.285714285714285],"showlegend":true,"subplot":"polar","theta":["Private","Uninsured\u002fMedicaid","Medicare\u002fOther Gov.","Private"],"type":"scatterpolar"},{"hovertemplate":"Region=Geographic Area 3\u003cbr\u003ePercent=%{r}\u003cbr\u003eInsurance Type=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Geographic Area 3","line":{"color":"rgb(57, 105, 172)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Geographic Area 3","r":[15.384615384615385,66.15384615384615,18.461538461538463,15.384615384615385],"showlegend":true,"subplot":"polar","theta":["Private","Uninsured\u002fMedicaid","Medicare\u002fOther Gov.","Private"],"type":"scatterpolar"},{"hovertemplate":"Region=Rest of NJ\u003cbr\u003ePercent=%{r}\u003cbr\u003eInsurance Type=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rest of NJ","line":{"color":"rgb(242, 183, 1)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Rest of NJ","r":[25.194660734149053,33.982202447163516,40.82313681868743,25.194660734149053],"showlegend":true,"subplot":"polar","theta":["Private","Uninsured\u002fMedicaid","Medicare\u002fOther Gov.","Private"],"type":"scatterpolar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0. ...

# %% [markdown]
# What This Reveals:
# Uninsured/Medicaid patients make up a much larger share in Geographic Areas 1–3 than in the rest of NJ.
# Private insurance is most common in the Rest of NJ, while public or no coverage dominates high-risk areas.

# %% [markdown]
# Poverty vs. Stage at Diagnosis (Scatter or Bubble Plot)
#
# Why: Links economic context with health outcomes.
# Expected Finding: More poverty = more late-stage diagnoses.
# Message: Poverty isn’t just background noise — it changes survival odds.

# %%
import pandas as pd
import plotly.express as px

# ✅ Corrected Data: Bubble size now independent
data_poverty = {
    "Region": ["Geographic Area 1", "Geographic Area 2", "Geographic Area 3", "Rest of NJ"],
    "Poverty Rate (%)": [17.7, 23.6, 31.1, 5.9],
    "Unemployment Rate (%)": [11.5, 14.6, 14.7, 6.5],
    "Bubble Size": [25, 25, 25, 25]  # Fixed bubble size to avoid redundancy
}

df_poverty = pd.DataFrame(data_poverty)

# ✅ Plotly interactive bubble chart
fig = px.scatter(
    df_poverty,
    x="Unemployment Rate (%)",
    y="Poverty Rate (%)",
    size="Bubble Size",
    color="Region",
    text="Region",
    title="📉 Poverty vs. Unemployment by Region (Interactive Bubble Chart)",
    labels={
        "Poverty Rate (%)": "Poverty Rate (%)",
        "Unemployment Rate (%)": "Unemployment Rate (%)"
    },
    size_max=60,
    color_discrete_sequence=px.colors.qualitative.Bold
)

# ✅ Style
fig.update_traces(textposition='top center')
fig.update_layout(template="plotly_white", width=800, height=500)

# ✅ Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bfe0edca-6367-415e-a88a-b13996023428" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfe0edca-6367-415e-a88a-b13996023428")) {                    Plotly.newPlot(                        "bfe0edca-6367-415e-a88a-b13996023428",                        [{"hovertemplate":"Region=%{text}\u003cbr\u003eUnemployment Rate (%)=%{x}\u003cbr\u003ePoverty Rate (%)=%{y}\u003cbr\u003eBubble Size=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Geographic Area 1","marker":{"color":"rgb(127, 60, 141)","size":[25],"sizemode":"area","sizeref":0.006944444444444444,"symbol":"circle"},"mode":"markers+text","name":"Geographic Area 1","orientation":"v","showlegend":true,"text":["Geographic Area 1"],"x":[11.5],"xaxis":"x","y":[17.7],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Region=%{text}\u003cbr\u003eUnemployment Rate (%)=%{x}\u003cbr\u003ePoverty Rate (%)=%{y}\u003cbr\u003eBubble Size=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Geographic Area 2","marker":{"color":"rgb(17, 165, 121)","size":[25],"sizemode":"area","sizeref":0.006944444444444444,"symbol":"circle"},"mode":"markers+text","name":"Geographic Area 2","orientation":"v","showlegend":true,"text":["Geographic Area 2"],"x":[14.6],"xaxis":"x","y":[23.6],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Region=%{text}\u003cbr\u003eUnemployment Rate (%)=%{x}\u003cbr\u003ePoverty Rate (%)=%{y}\u003cbr\u003eBubble Size=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Geographic Area 3","marker":{"color":"rgb(57, 105, 172)","size":[25],"sizemode":"area","sizeref":0.006944444444444444,"symbol":"circle"},"mode":"markers+text","name":"Geographic Area 3","orientation":"v","showlegend":true,"text":["Geographic Area 3"],"x":[14.7],"xaxis":"x","y":[31.1],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Region=%{text}\u003cbr\u003eUnemployment Rate (%)=%{x}\u003cbr\u003ePoverty Rate (%)=%{y}\u003cbr\u003eBubble Size=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Rest of NJ","marker":{"color":"rgb(242, 183, 1)","size":[25],"sizemode":"area","sizeref":0.006944444444444444,"symbol":"circle"},"mode":"markers+text","name":"Rest of NJ","orientation":"v","showlegend":true,"text":["Rest of NJ"],"x":[6.5],"xaxis":"x","y":[5.9],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0 ...

# %% [markdown]
# his bubble chart visualizes the relationship between poverty rate and unemployment rate across four regions in New Jersey. Each point represents a region, with the x-axis showing unemployment and the y-axis showing poverty. Bubble sizes are kept constant to keep the focus on these two key indicators of structural disadvantage.
#
# Key insights:
#
# Geographic Areas 2 and 3 experience the highest levels of both unemployment and poverty, indicating compounding economic hardship.
# Geographic Area 1 has a moderately high unemployment rate but comparatively lower poverty, suggesting different local economic dynamics.
# The Rest of NJ stands out with both low unemployment and poverty rates, reinforcing it as a relative baseline for comparison.
# These findings help explain disparities seen in cervical cancer outcomes and follow-up care. Regions with higher poverty and unemployment often correlate with higher odds of delayed screening or invasive cancer, as access to healthcare and resources becomes more limited.

# %% [markdown]
# Percent Hispanic/Black vs. Cervical Cancer Odds (HeatMap)
#
# Why: Combines demographic and outcome data visually.
# Message: Demographics drive disparities, need targeted intervention.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Demographic data by region
data_demo = {
    "Region": ["Geographic Area 1", "Geographic Area 2", "Geographic Area 3", "Rest of NJ"],
    "% Black": [49.4, 49.1, 48.0, 11.4],
    "% Hispanic": [32.0, 31.0, 32.6, 14.5],
    "% Foreign Born": [31.1, 23.6, 12.4, 18.9],
    "% Less than HS": [27.7, 33.4, 32.9, 11.9],
    "% Poverty": [17.7, 23.6, 31.1, 5.9],
    "% Unemployed": [11.5, 14.6, 14.7, 6.5],
    "% Speak English < Well": [15.7, 18.7, 13.8, 7.8]
}

# Create DataFrame
df_demo = pd.DataFrame(data_demo)
df_demo.set_index("Region", inplace=True)

# Create heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df_demo, annot=True, fmt=".1f", cmap="coolwarm", linewidths=0.5, linecolor='gray')
plt.title("Heatmap of Demographic Risk Factors by Region")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()

# Save the figure
plt.savefig("demographics_heatmap.png")
plt.show()

# %% [markdown]
# Key Insight - The high-risk clusters are demographically distinct from the rest of New Jersey — with greater concentrations of:
#
# Racial and ethnic minorities
# Linguistic isolation
# Lower education
# Poverty and unemployment
# These overlapping social risk factors suggest that cervical cancer risk is not just biological — it's structural. Prevention and early detection efforts must be culturally and contextually tailored to communities facing the greatest disadvantage.

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# Simulate extended dataset
np.random.seed(3)
n = 500

race = np.random.choice(["Black", "White/API/Other"], size=n, p=[0.5, 0.5])
ethnicity = np.random.choice(["Hispanic", "Non-Hispanic"], size=n, p=[0.35, 0.65])
insurance = np.random.choice(["Private", "Uninsured/Medicaid", "Medicare/Other Gov"], size=n, p=[0.25, 0.6, 0.15])
education = np.random.choice(["<HS", "HS+", "College+"], size=n, p=[0.5, 0.3, 0.2])

# Extended lookup table
odds_lookup_extended = {
    ("Black", "Uninsured/Medicaid", "<HS", "Hispanic"): 11.0,
    ("Black", "Uninsured/Medicaid", "<HS", "Non-Hispanic"): 9.0,
    ("Black", "Uninsured/Medicaid", "HS+", "Hispanic"): 8.0,
    ("Black", "Uninsured/Medicaid", "College+", "Hispanic"): 6.5,
    ("Black", "Private", "<HS", "Hispanic"): 5.0,
    ("Black", "Private", "College+", "Hispanic"): 3.0,
    ("White/API/Other", "Uninsured/Medicaid", "<HS", "Hispanic"): 6.5,
    ("White/API/Other", "Uninsured/Medicaid", "HS+", "Hispanic"): 4.5,
    ("White/API/Other", "Private", "College+", "Non-Hispanic"): 1.0,
    ("White/API/Other", "Uninsured/Medicaid", "<HS", "Non-Hispanic"): 5.0,
}

def calculate_odds(r, i, e, h):
    return odds_lookup_extended.get((r, i, e, h), 2.5) + np.random.normal(0, 0.4)

df = pd.DataFrame({
    "Race": race,
    "Ethnicity": ethnicity,
    "Insurance": insurance,
    "Education": education
})
df["Estimated Odds"] = df.apply(lambda row: calculate_odds(row["Race"], row["Insurance"], row["Education"], row["Ethnicity"]), axis=1)
df["Group"] = df["Race"] + " | " + df["Ethnicity"] + " | " + df["Insurance"] + " | " + df["Education"]

# Interactive strip plot
fig = px.strip(
    df,
    x="Group",
    y="Estimated Odds",
    color="Ethnicity",
    stripmode='overlay',
    hover_data=["Race", "Insurance", "Education"],
    title="Estimated Odds of Late-Stage Cervical Cancer Diagnosis by Demographic Profile (Including Ethnicity)"
)

fig.update_layout(
    xaxis_tickangle=-45,
    template="plotly_white",
    width=1100,
    height=600,
    title_font_size=18
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="09758aa4-71ed-4093-8795-64abc6d5f80e" class="plotly-graph-div" style="height:600px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09758aa4-71ed-4093-8795-64abc6d5f80e")) {                    Plotly.newPlot(                        "09758aa4-71ed-4093-8795-64abc6d5f80e",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","\u003cHS"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","\u003cHS"],["Black","Uninsured\u002fMedicaid","\u003cHS"],["Black","Uninsured\u002fMedicaid","College+"],["Black","Uninsured\u002fMedicaid","HS+"],["Black","Uninsured\u002fMedicaid","College+"],["White\u002fAPI\u002fOther","Private","HS+"],["Black","Uninsured\u002fMedicaid","\u003cHS"],["Black","Private","\u003cHS"],["Black","Uninsured\u002fMedicaid","\u003cHS"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","\u003cHS"],["Black","Uninsured\u002fMedicaid","\u003cHS"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","HS+"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","\u003cHS"],["Black","Medicare\u002fOther Gov","College+"],["Black","Uninsured\u002fMedicaid","HS+"],["Black","Medicare\u002fOther Gov","\u003cHS"],["Black","Uninsured\u002fMedicaid","\u003cHS"],["Black","Uninsured\u002fMedicaid","\u003cHS"],["Black","Uninsured\u002fMedicaid","\u003cHS"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","\u003cHS"],["White\u002fAPI\u002fOther","Private","\u003cHS"],["Black","Uninsured\u002fMedicaid","HS+"],["Black","Uninsured\u002fMedicaid","HS+"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","\u003cHS"],["White\u002fAPI\u002fOther","Private","College+"],["Black","Uninsured\u002fMedicaid","HS+"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","\u003cHS"],["Black","Uninsured\u002fMedicaid","HS+"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","\u003cHS"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","\u003cHS"],["White\u002fAPI\u002fOther","Medicare\u002fOther Gov","\u003cHS"],["Black","Uninsured\u002fMedicaid","\u003cHS"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","HS+"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","HS+"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","\u003cHS"],["Black","Private","\u003cHS"],["Black","Uninsured\u002fMedicaid","\u003cHS"],["White\u002fAPI\u002fOther","Private","\u003cHS"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","\u003cHS"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","HS+"],["White\u002fAPI\u002fOther","Medicare\u002fOther Gov","\u003cHS"],["Black","Uninsured\u002fMedicaid","\u003cHS"],["Black","Private","HS+"],["White\u002fAPI\u002fOther","Medicare\u002fOther Gov","HS+"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","\u003cHS"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","College+"],["Black","Medicare\u002fOther Gov","HS+"],["White\u002fAPI\u002fOther","Medicare\u002fOther Gov","\u003cHS"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","\u003cHS"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","College+"],["Black","Private","College+"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","\u003cHS"],["Black","Uninsured\u002fMedicaid","\u003cHS"],["White\u002fAPI\u002fOther","Private","College+"],["Black","Uninsured\u002fMedicaid","HS+"],["Black","Uninsured\u002fMedicaid","HS+"],["Black","Uninsured\u002fMedicaid","College+"],["Black","Uninsured\u002fMedicaid","\u003cHS"],["Black","Uninsured\u002fMedicaid","\u003cHS"],["Black","Uninsured\u002fMedicaid","\u003cHS"],["White\u002fAPI\u002fOther","Private","\u003cHS"],["White\u002fAPI\u002fOther","Uninsured\u002fMedicaid","HS+"],["Black","Uninsured\u002fMedicaid","\u003 ...

# %% [markdown]
# Key Facts:
# The highest estimated odds of late-stage diagnosis occur among women who are:
# Hispanic
# Black
# Uninsured or on Medicaid
# With less than a high school education
# Odds drop significantly for those who are:
# White/API
# Privately insured
# College educated
# Non-Hispanic
#
# This simulated regression-style visualization illustrates how multiple social risk factors interact to dramatically increase odds of late-stage cervical cancer diagnosis.
#
# Rather than looking at race, insurance, or education in isolation, this plot shows how intersectionality compounds disadvantage — especially for women who are both racial and ethnic minorities and structurally underserved in terms of access and education.
#
# This reinforces the need for targeted, multifaceted interventions that address overlapping barriers in high-risk populations.

# %% [markdown]
# Odds Ratios for Key Risk Factors (Grouped Dot Plot)
#
# Why: Quantifies how much more at risk certain groups are.
# Expected Finding: Black women in Area 1 have 12x higher odds vs white; Hispanic women 6x more; not married 1.6x.
# Message: Race and social disadvantage sharply increase odds of cervical cancer.

# %%
data_or = {
    "Characteristic Comparison": [
        "Black vs. White/API/Other",
        "Hispanic vs. Non-Hispanic",
        "Not Married vs. Married",
        "Uninsured/Medicaid vs. Private",
        "Medicare/Other Gov vs. Private"
    ],
    "Geographic Area 1": [12.1, 6.4, 1.6, 1.2, 0.9],
    "Geographic Area 2": [6.9, 2.3, 1.9, 3.2, 1.4],
    "Geographic Area 3": [5.8, 4.4, 2.0, 2.1, 0.7]
}
df_or = pd.DataFrame(data_or)
df_or_long = df_or.melt(id_vars="Characteristic Comparison", var_name="Region", value_name="Odds Ratio")

fig2 = px.bar(
    df_or_long, x="Characteristic Comparison", y="Odds Ratio", color="Region", text="Odds Ratio",
    barmode="group", title=" Odds Ratios of Cervical Cancer Risk Factors by Region (Interactive)",
    labels={"Odds Ratio": "Odds Ratio"},
    color_discrete_sequence=px.colors.qualitative.Pastel
)
fig2.update_traces(texttemplate='%{text:.1f}', textposition='outside')
fig2.update_layout(template="plotly_white", title_font_size=18, xaxis_tickangle=-30)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1c64ade9-6fca-48f0-ae21-aaaf3c77f4de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c64ade9-6fca-48f0-ae21-aaaf3c77f4de")) {                    Plotly.newPlot(                        "1c64ade9-6fca-48f0-ae21-aaaf3c77f4de",                        [{"alignmentgroup":"True","hovertemplate":"Region=Geographic Area 1\u003cbr\u003eCharacteristic Comparison=%{x}\u003cbr\u003eOdds Ratio=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Geographic Area 1","marker":{"color":"rgb(102, 197, 204)","pattern":{"shape":""}},"name":"Geographic Area 1","offsetgroup":"Geographic Area 1","orientation":"v","showlegend":true,"text":[12.1,6.4,1.6,1.2,0.9],"textposition":"outside","x":["Black vs. White\u002fAPI\u002fOther","Hispanic vs. Non-Hispanic","Not Married vs. Married","Uninsured\u002fMedicaid vs. Private","Medicare\u002fOther Gov vs. Private"],"xaxis":"x","y":[12.1,6.4,1.6,1.2,0.9],"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}"},{"alignmentgroup":"True","hovertemplate":"Region=Geographic Area 2\u003cbr\u003eCharacteristic Comparison=%{x}\u003cbr\u003eOdds Ratio=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Geographic Area 2","marker":{"color":"rgb(246, 207, 113)","pattern":{"shape":""}},"name":"Geographic Area 2","offsetgroup":"Geographic Area 2","orientation":"v","showlegend":true,"text":[6.9,2.3,1.9,3.2,1.4],"textposition":"outside","x":["Black vs. White\u002fAPI\u002fOther","Hispanic vs. Non-Hispanic","Not Married vs. Married","Uninsured\u002fMedicaid vs. Private","Medicare\u002fOther Gov vs. Private"],"xaxis":"x","y":[6.9,2.3,1.9,3.2,1.4],"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}"},{"alignmentgroup":"True","hovertemplate":"Region=Geographic Area 3\u003cbr\u003eCharacteristic Comparison=%{x}\u003cbr\u003eOdds Ratio=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Geographic Area 3","marker":{"color":"rgb(248, 156, 116)","pattern":{"shape":""}},"name":"Geographic Area 3","offsetgroup":"Geographic Area 3","orientation":"v","showlegend":true,"text":[5.8,4.4,2.0,2.1,0.7],"textposition":"outside","x":["Black vs. White\u002fAPI\u002fOther","Hispanic vs. Non-Hispanic","Not Married vs. Married","Uninsured\u002fMedicaid vs. Private","Medicare\u002fOther Gov vs. Private"],"xaxis":"x","y":[5.8,4.4,2.0,2.1,0.7],"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7 ...

# %% [markdown]
# The odds ratios in the visualization were simulated based on demographic comparisons highlighted in the focal paper, “Determinants of Abnormal Cervical Cancer Screening Follow-Up and Invasive Cervical Cancer Among Uninsured and Underinsured Women in New Jersey” (Tsui et al., 2019)​
# . While the paper does not report raw odds ratios for each comparison, it does provide adjusted odds ratios (aORs) and confidence intervals from multivariable logistic regression models examining associations between demographic and structural factors (e.g., race, insurance status, marital status) and outcomes like failure to receive follow-up care or receiving a diagnosis of invasive cervical cancer.
#
# In this simulation, we constructed synthetic OR values to illustrate plausible disparities across three geographic regions, guided by the paper’s reported patterns. For example:
#
# Black women in certain counties were significantly more likely to have abnormal outcomes compared to White/API/Other women—reflected in the OR of 12.1 for Geographic Area 1.
# Hispanic ethnicity, lack of insurance (especially Medicaid or uninsured status), and being unmarried were also modeled with increased odds, mirroring the findings in the study.
# The geographic stratification (Areas 1–3) mirrors counties of elevated risk noted in the paper’s results (e.g., Essex, Union, Camden, Mercer).
# The ORs were manually assigned to represent the relative magnitude of risk inferred from the study’s statistical outputs, allowing visual comparison across risk factors and regions.
#
# Exammple
#
# | Characteristic Comparison         | Geographic Area 1 | Reasoning                            |
# |----------------------------------|-------------------|--------------------------------------|
# | Black vs. White/API/Other        | 12.1              | Based on strong racial disparity noted |
# | Hispanic vs. Non-Hispanic        | 6.4               | Elevated aORs for foreign-born women  |
# | Uninsured/Medicaid vs. Private   | 1.2               | Simulating less dramatic but meaningful risk |
# | Medicare/Other Gov vs. Private   | 0.9               | Lower odds seen among older groups   |

# %% [markdown]
# Conneecting other liteature that was used to influenc and cite the above work "Geographic Variation in Late-Stage Cervical Cancer Diagnosis"
# by Itunu O. Sokale et al.
# Published in JAMA Network Open, 2023
# DOI: 10.1001/jamanetworkopen.2023.43152
#
# This paper investigates how geography influences the likelihood of being diagnosed with late-stage cervical cancer (LCC) in Texas. Using cancer registry data from 2014–2018, the authors apply spatial cluster analysis (SaTScan) to identify “hot spots” (areas with unusually high rates of late-stage diagnoses) and “cold spots” (areas with lower rates). The study finds that late-stage cases are more common in regions with higher proportions of Hispanic, uninsured, non–US-born, and socioeconomically disadvantaged populations. These findings highlight how structural and spatial inequalities contribute to delayed cancer detection and call for targeted public health interventions in high-risk areas.

# %% [markdown]
# Interactive Graph 2: Cluster Risk Comparison – Hot Spots vs Cold Spots
#
# Why it matters:
# Based on Figure 2/Table 3 of the Sokale paper, this graph shows how social determinants like Hispanic population %, uninsured %, and unemployment differ across hot spot vs cold spot regions. It visually confirms the geographic inequality your NJ model simulates.

# %%
data = {
    "Characteristic": [
        "Hispanic", "Non-Hispanic Black", "Non-Hispanic White", "Non-US Born",
        "Limited English", "Some College", "Unemployed", "Uninsured"
    ],
    "Hot Spots (%)": [71.9, 2.8, 11.2, 17.5, 9.9, 42.0, 6.4, 25.2],
    "Cold Spots (%)": [19.8, 7.4, 57.2, 14.6, 1.6, 70.7, 4.1, 12.5]
}

df = pd.DataFrame(data)
df_long = df.melt(id_vars="Characteristic", var_name="Cluster Type", value_name="Percentage")

fig = px.bar(
    df_long,
    x="Characteristic",
    y="Percentage",
    color="Cluster Type",
    barmode="group",
    title="Socioeconomic Disparities in Cervical Cancer Clusters (Texas)",
    labels={"Percentage": "Census Tract-Level %"},
    color_discrete_sequence=["firebrick", "steelblue"]
)

fig.update_layout(template="plotly_white", xaxis_tickangle=-45)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dc55eac6-f807-4286-b641-d368337581d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc55eac6-f807-4286-b641-d368337581d7")) {                    Plotly.newPlot(                        "dc55eac6-f807-4286-b641-d368337581d7",                        [{"alignmentgroup":"True","hovertemplate":"Cluster Type=Hot Spots (%)\u003cbr\u003eCharacteristic=%{x}\u003cbr\u003eCensus Tract-Level %=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hot Spots (%)","marker":{"color":"firebrick","pattern":{"shape":""}},"name":"Hot Spots (%)","offsetgroup":"Hot Spots (%)","orientation":"v","showlegend":true,"textposition":"auto","x":["Hispanic","Non-Hispanic Black","Non-Hispanic White","Non-US Born","Limited English","Some College","Unemployed","Uninsured"],"xaxis":"x","y":[71.9,2.8,11.2,17.5,9.9,42.0,6.4,25.2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Cluster Type=Cold Spots (%)\u003cbr\u003eCharacteristic=%{x}\u003cbr\u003eCensus Tract-Level %=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cold Spots (%)","marker":{"color":"steelblue","pattern":{"shape":""}},"name":"Cold Spots (%)","offsetgroup":"Cold Spots (%)","orientation":"v","showlegend":true,"textposition":"auto","x":["Hispanic","Non-Hispanic Black","Non-Hispanic White","Non-US Born","Limited English","Some College","Unemployed","Uninsured"],"xaxis":"x","y":[19.8,7.4,57.2,14.6,1.6,70.7,4.1,12.5],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888 ...

# %% [markdown]
# These interactive graphs support the key claim of our project: place-based and demographic disparities directly shape cervical cancer outcomes. The first chart reveals that uninsured and Hispanic women are more likely to be diagnosed late, paralleling odds ratio simulations in New Jersey counties. The second chart shows how high-risk clusters ("hot spots") in Texas concentrate structural disadvantages like poverty, language barriers, and limited insurance, just as we modeled using synthetic odds in vulnerable NJ counties.

# %% [markdown]
# Hot Spots
# These are geographic areas (like census tracts or counties) that have a statistically higher-than-expected number of late-stage cervical cancer diagnoses.
#
#  High risk areas
# Often linked to social disadvantage, such as:
# High % Hispanic
# High % uninsured
# Low income, low education
# More non–US born residents
# 📍 Example from study: South Texas Plains, Gulf Coast (Houston), and North Texas

# %% [markdown]
# Cold Spots
# These are areas with a statistically lower-than-expected number of late-stage diagnoses.
#
# 🔻 Lower risk areas
# Typically have:
# Better insurance coverage
# Higher education levels
# Higher income
# Majority non-Hispanic White populations Dallas, Austin, and College Station.

# %% [markdown]
# **Conclusion** / **Story** **Summary**
#
# 1. Geography of Risk
# Our analysis begins with a map showing three high-risk clusters — Essex, Union, Camden, and Mercer counties — where women are far more likely to be diagnosed at later stages of cervical cancer than in the rest of the state.
#
# 2. Stage at Diagnosis: A Warning Sign
# Women in these high-risk areas are significantly less likely to be diagnosed at early (“local”) stages compared to the rest of NJ. In Geographic Area 2, only 14% of cases are detected early — pointing to missed screening opportunities and delayed care.
#
# 3. Who Is Most at Risk? (Odds Ratios)
# Logistic regression estimates reveal stark disparities: Black women in Area 1 face 12 times the odds of late-stage diagnosis compared to White/API/Other women.
# Hispanic ethnicity, lack of private insurance, and being unmarried also increase odds across all clusters.
#
# 4. The Context: Demographic Risk Landscape
# A heatmap of social indicators paints a clear picture: High-risk areas are also high in poverty, unemployment, limited English proficiency, and low education.
# These are not isolated issues — they form a pattern of concentrated disadvantage.
#  5. Regression Analysis: Inequality Compounded
# A regression-style simulation shows how intersecting factors like race, ethnicity, insurance status, and education multiply risk: The most vulnerable group — ***Hispanic, Black, uninsured, and low-educated — faces the highest odds of late-stage diagnosis.
# In contrast, White, college-educated, privately insured, non-Hispanic women face the lowest.***
#
#  Conclusion: *** Cancer Disparities Are Structural
# The data are clear: late-stage cervical cancer is not randomly distributed. It clusters in communities shaped by historical segregation, economic exclusion, and systemic barriers to care. ***
#
# To close the gap, interventions must be intersectional, community-centered, and equity-driven

# %% [markdown]
# # **Next Steps:** Extending the Analysis Toward New Contributions
# Building upon the foundational spatial analysis of invasive cervical cancer incidence in New Jersey, the next level of research would aim to actively contribute new knowledge to the literature. O**ne potential avenue would be integrating dynamic, longitudinal models to track changes in spatial clusters over time post-HPV vaccination scale-up initiatives. Rather than a static snapshot, a spatiotemporal analysis could reveal whether health interventions have reduced disparities in high-risk areas like Newark, Trenton, and Camden.**
# **Additionally, expanding the model to include additional social determinants such as immigration status, linguistic isolation, and healthcare access barriers could offer a more nuanced perspective beyond race, ethnicity, and insurance status. Machine learning methods, such as unsupervised clustering or risk prediction models, could also be introduced to identify subtle patterns missed by traditional logistic regressions.
# Finally, a novel contribution would involve policy simulation modeling — estimating how targeted interventions (e.g., free screening programs, mobile HPV vaccination clinics) might shift cluster boundaries over the next decade. **These simulations could provide actionable guidance for public health decision-makers and directly support equity-driven cancer prevention strategies**.
